# %% [markdown]
# ## Практическая работа

# %% [markdown]
# В этой практической работе четыре обязательные задачи.
#
# *Обязательные задачи* нужно сделать для того, чтобы проверить, что вы действительно усвоили материал модуля. Сдайте их на проверку.
#
# Удачи!

# %% [markdown]
# Цели практической работы:
#
#
# 1.   Потренироваться в обучении моделей деревьев решений.
# 2.   Потренироваться в обучении моделей случайного леса.
# 3.   Научиться оценивать качество моделей с помошью Accuracy и confusion matrix.
# 4.   Научиться увеличивать качество моделей с помощью тюнинга параметров.

# %% [markdown]
# Что оценивается:
#
# *   Все пункты и критерия приёмки задания выполнены.
# *   Удаление колонок по результатам feature_importance и определения типов производится с помощью кода, а не перечислением их вручную.

# %% [markdown]
# ## Обязательные задачи

# %% [markdown]
# ### Описание датасета:
# - `id`: идентификатор записи;
# - `is_manufacturer_name`: признак производителя автомобиля;
#
# - `region_*`: регион;
# - `x0_*`: тип топлива;
# - `manufacturer_*`: производитель;
# - `short_model_*`: сокращённая модель автомобиля;
# - `title_status_*`: статус;
# - `transmission_*`: коробка передач;
# - `state_*`: штат;
# - `age_category_*`: возрастная категория автомобиля;
#
# - `std_scaled_odometer`: количество пройденных миль (после стандартизации);
# - `year_std`: год выпуска (после стандартизации);
# - `lat_std`: широта (после стандартизации);
# - `long_std`: долгота (после стандартизации);
# - `odometer/price_std`: отношение стоимости к пробегу автомобиля (после стандартизации);
# - `desc_len_std`: количество символов в тексте объявления о продаже (после стандартизации);
# - `model_in_desc_std`: количество наименований модели автомобиля в тексте объявления о продаже (после стандартизации);
# - `model_len_std`: длина наименования автомобиля (после стандартизации);
# - `model_word_count_std`: количество слов в наименовании автомобиля (после стандартизации);
# - `month_std`: номер месяца размещения объявления о продаже автомобиля (после стандартизации);
# - `dayofweek_std`: день недели размещения объявления о продаже автомобиля (после стандартизации);
# - `diff_years_std`: количество лет между годом производства автомобиля и годом размещения объявления о продаже автомобиля (после стандартизации);
#
# - `price`: стоимость;
# - `price_category`: категория цены.

# %% [markdown]
# 0. *Подготовка базовой модели*
#
# Обучите простую модель классификации с помощью DecisionTreeClassifier на данных из датасета vehicles_dataset_prepared.csv. Для этого сделайте следующие шаги:
#
# 1. Обучите модель дерева решений с зафиксированным random_state на тренировочной выборке.
# 2. Сделайте предикт на тестовой выборке.
# 3. Замерьте точность на тестовой выборке и выведите матрицу ошибок.
# 4. Удалите фичи с нулевыми весами по feature_importance из тренировочной и тестовой выборок.
# 5. Заново обучите модель и измерьте качество.

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df = pd.read_csv('vehicles_dataset_prepared.csv')

df_prepared = df.copy()
df_prepared = df_prepared.drop(['price', 'odometer/price_std'], axis=1)

x = df_prepared.drop(['price_category'], axis=1)
y = df_prepared['price_category']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predicted_train = clf.predict(x_train)
predicted_test = clf.predict(x_test)

# %%
print(accuracy_score(y_train, predicted_train))
print(accuracy_score(y_test, predicted_test))
# Out:
# 1.0
# 0.6763686763686764

# %%
confusion_matrix(y_test, predicted_test)
# Out:
# array([[754,  48, 195],
#        [ 44, 684, 225],
#        [193, 229, 514]], dtype=int64)

# %%
print(clf.feature_importances_)
f_imp_list = list(zip(x_train.columns, clf.feature_importances_))
f_imp_list.sort(key=lambda x: x[1], reverse=True)
f_imp_list
# Out:
# [0.03493463 0.00041354 0.00398895 ... 0.00198182 0.01370828 0.04644872]
# [('age_category_new', 0.17513190799837453),
#  ('std_scaled_odometer', 0.08205603473322241),
#  ('model_len_std', 0.07526591920844955),
#  ('desc_len_std', 0.06902443066082281),
#  ('diff_years_std', 0.046448718757734764),
#  ('lat_std', 0.04067999151012282),
#  ('long_std', 0.039877021985337664),
#  ('id', 0.03493463433238924),
#  ('x0_diesel', 0.03343217370499131),
#  ('year_std', 0.018466068603418092),
#  ('dayofweek_std', 0.013708275789319706),
#  ('manufacturer_kia', 0.009641023167085214),
#  ('manufacturer_ram', 0.00930564979716938),
#  ('short_model_wrangler', 0.009122693055663381),
#  ('model_word_count_std', 0.006416346748669162),
#  ('short_model_f-150', 0.006313878562102588),
#  ('manufacturer_gmc', 0.005997688801060967),
#  ('manufacturer_hyundai', 0.005663759938057569),
#  ('manufacturer_volkswagen', 0.004980611895019879),
#  ('short_model_Scion', 0.004865746378858323),
#  ('short_model_silverado', 0.004726832932624164),
#  ('manufacturer_mercedes-benz', 0.004614266590743074),
#  ('manufacturer_dodge', 0.004143470446860373),
#  ('manufacturer_chevrolet', 0.004012898404611148),
#  ('is_ford', 0.003988947559057289),
#  ('manufacturer_rover', 0.0037924786619157745),
#  ('short_model_tacoma', 0.0037907587797259244),
#  ('transmission_automatic', 0.0037217183561586305),
#  ('model_in_desc_std', 0.0036340376272985253),
#  ('manufacturer_bmw', 0.0033304989040390566),
#  ('is_chevrolet', 0.0030947542456268916),
#  ('short_model_corolla', 0.002988157132822548),
#  ('title_status_clean', 0.002856538931562722),
#  ('manufacturer_nissan', 0.0027817724478200892),
#  ('short_model_sierra', 0.0026756164553782425),
#  ('short_model_escape', 0.0026624560293846897),
#  ('short_model_f-250', 0.0026483906046178853),
#  ('x0_gas', 0.00262964781416874),
#  ('title_status_rebuilt', 0.0025260001432918064),
#  ('short_model_cruze', 0.0025245691829843637),
#  ('manufacturer_honda', 0.002523402135657344),
#  ('short_model_mustang', 0.002431210409027671),
#  ('short_model_f150', 0.0023515824544503927),
#  ('short_model_trax', 0.0023491045266455764),
#  ('state_ny', 0.002240318471565754),
#  ('short_model_jetta', 0.0022269001588705486),
#  ('short_model_spark', 0.0022086387388075687),
#  ('short_model_focus', 0.002134302847024726),
#  ('manufacturer_chrysler', 0.0020875412916620028),
#  ('manufacturer_other', 0.0020671892440872913),
#  ('short_model_4runner', 0.002061138730489657),
#  ('short_model_sentra', 0.002058449219922339),
#  ('short_model_fj', 0.002045890084399617),
#  ('manufacturer_buick', 0.0020254625573822597),
#  ('manufacturer_cadillac', 0.001993418307080079),
#  ('month_std', 0.0019818200432013804),
#  ('region_south florida', 0.0019619490868169566),
#  ('short_model_tundra', 0.001932974098416757),
#  ('short_model_camry', 0.0019029049097887799),
#  ('manufacturer_lexus', 0.0018870959185146993),
#  ('short_model_x5', 0.0018650679374963381),
#  ('manufacturer_mitsubishi', 0.001862076163455095),
#  ('state_mi', 0.0017832905797459016),
#  ('manufacturer_ford', 0.001779247024058371),
#  ('state_nc', 0.001778623752061228),
#  ('state_nm', 0.0017484974698145838),
#  ('is_toyota', 0.0016504278401344265),
#  ('region_minneapolis / st paul', 0.0016322245208195787),
#  ('x0_other', 0.001614999868379398),
#  ('short_model_express', 0.00157964969057315),
#  ('short_model_other', 0.0015432026434522455),
#  ('short_model_f-350', 0.001528970546918455),
#  ('state_nj', 0.0015244635193648781),
#  ('region_raleigh / durham / CH', 0.001517615794768656),
#  ('state_co', 0.0014994254081353246),
#  ('short_model_versa', 0.0014943008872708463),
#  ('short_model_altima', 0.001483509401680888),
#  ('state_fl', 0.001483468793252794),
#  ('short_model_civic', 0.001460601214907929),
#  ('short_model_transit', 0.0014157502678450247),
#  ('short_model_fusion', 0.0013937017332275228),
#  ('age_category_old', 0.001388837596350001),
#  ('short_model_elantra', 0.0013864423281385956),
#  ('x0_hybrid', 0.0013858022386644177),
#  ('state_wi', 0.0013716431001402625),
#  ('state_il', 0.0013605277912695501),
#  ('short_model_tahoe', 0.0013581064030962003),
#  ('manufacturer_mazda', 0.0013188375199902757),
#  ('short_model_mazda3', 0.0013096991082697609),
#  ('short_model_f250', 0.0012907612119133199),
#  ('region_philadelphia', 0.0012435286712648513),
#  ('region_flint', 0.0012263775472838346),
#  ('region_colorado springs', 0.00121519536173709),
#  ('region_nashville', 0.0011853261371336636),
#  ('region_orlando', 0.0011825401607060172),
#  ('manufacturer_jeep', 0.0011814461417952702),
#  ('short_model_colorado', 0.0011795274230073408),
#  ('region_tucson', 0.0011676254338028693),
#  ('short_model_golf', 0.0011490793734410107),
#  ('state_id', 0.001142322354040707),
#  ('state_az', 0.0011384787713764157),
#  ('age_category_average', 0.0011288947307229954),
#  ('short_model_titan', 0.0011238794772212364),
#  ('short_model_challenger', 0.0011196805603906099),
#  ('state_ct', 0.0011179120371173539),
#  ('short_model_malibu', 0.0011124625243675195),
#  ('state_tx', 0.0010933254575203459),
#  ('manufacturer_acura', 0.0010848397031025267),
#  ('manufacturer_toyota', 0.0010798186827026585),
#  ('state_ms', 0.0010752967078554746),
#  ('short_model_super', 0.0010746101453129352),
#  ('title_status_lien', 0.0010559145866345088),
#  ('short_model_avalanche', 0.0010524209405548852),
#  ('region_los angeles', 0.0010344344400521081),
#  ('short_model_corvette', 0.0009957858969400686),
#  ('manufacturer_subaru', 0.0009818358851096736),
#  ('region_yuba-sutter', 0.000948526211716502),
#  ('title_status_salvage', 0.0009314591346585287),
#  ('short_model_land', 0.0009309281324858938),
#  ('state_ia', 0.0009291605454839381),
#  ('transmission_manual', 0.0009282915834573308),
#  ('short_model_promaster', 0.0009171318438944541),
#  ('short_model_regal', 0.0009050019395910673),
#  ('short_model_escalade', 0.0008803002820096952),
#  ('region_little rock', 0.0008737286459564426),
#  ('manufacturer_infiniti', 0.0008709619730677191),
#  ('short_model_edge', 0.0008591705098430152),
#  ('region_worcester / central MA', 0.0008540334049817443),
#  ('short_model_f650', 0.0008395216748567142),
#  ('short_model_outlander', 0.0008362554471851332),
#  ('short_model_sonic', 0.0008282077690209492),
#  ("region_spokane / coeur d'alene", 0.0008281218133616707),
#  ('short_model_gx', 0.0008275149241330076),
#  ('short_model_500', 0.0008269082904487315),
#  ('region_palm springs', 0.0008229114485748154),
#  ('short_model_tiguan', 0.0008226106576272183),
#  ('region_lakeland', 0.0008211703238826313),
#  ('region_pittsburgh', 0.0008209224416132373),
#  ('region_omaha / council bluffs', 0.0008188010489193416),
#  ('region_southern illinois', 0.0008185378615672285),
#  ('state_ky', 0.0008156901024246601),
#  ('state_mt', 0.0008112425416459784),
#  ('short_model_fit', 0.0008019016305891079),
#  ('region_cincinnati', 0.0007910137460043811),
#  ('short_model_impreza', 0.0007821018312122641),
#  ('short_model_mirage', 0.0007731098933828734),
#  ('region_stockton', 0.0007673468682639529),
#  ('state_va', 0.0007598882017866995),
#  ('state_pa', 0.0007549272377992129),
#  ('region_yakima', 0.000753474625503068),
#  ('region_boulder', 0.0007497492127952579),
#  ('region_reno / tahoe', 0.0007489431704846445),
#  ('transmission_other', 0.0007469378669445372),
#  ('region_dallas / fort worth', 0.0007452199344198783),
#  ('short_model_a4', 0.0007450229788747671),
#  ('short_model_explorer', 0.0007436298286466744),
#  ('state_oh', 0.000737575630034231),
#  ('short_model_1500', 0.0007374811437909026),
#  ('region_madison', 0.0007368305288825639),
#  ('short_model_santa', 0.0007318007516961128),
#  ('state_sc', 0.0007295875388186539),
#  ('manufacturer_volvo', 0.0007281299767568722),
#  ('region_portland', 0.0007276494127666002),
#  ('state_tn', 0.0007249984123052827),
#  ('short_model_e-350', 0.0007127535996839998),
#  ('manufacturer_mini', 0.0007124298206997199),
#  ('short_model_qx50', 0.0007121771029978719),
#  ('short_model_impala', 0.0007100153701126202),
#  ('region_kansas city, MO', 0.0006967720224425805),
#  ('x0_electric', 0.0006947852275420484),
#  ('region_grand rapids', 0.000679034424495035),
#  ('short_model_rx', 0.0006786696263304666),
#  ('short_model_pilot', 0.0006684245116123),
#  ('state_nv', 0.0006449710199767809),
#  ('region_ventura county', 0.0006389189039350638),
#  ('short_model_cooper', 0.000631872926179334),
#  ('short_model_highlander', 0.0006307964184760851),
#  ('short_model_dart', 0.0006275088293863341),
#  ('region_tampa bay area', 0.0006259848600813603),
#  ('short_model_330xi', 0.0006237978728096295),
#  ('state_ca', 0.0006189115848262036),
#  ('region_norfolk / hampton roads', 0.0006147686664624693),
#  ('short_model_f-250sd', 0.0006139008617778532),
#  ('state_de', 0.0006117167827102285),
#  ('region_wenatchee', 0.0006006585935467864),
#  ('short_model_odyssey', 0.0005950449650910586),
#  ('region_eastern NC', 0.0005778591706008183),
#  ('manufacturer_lincoln', 0.0005737998070877606),
#  ('region_bend', 0.0005607338958525407),
#  ('region_charlotte', 0.0005575828756015077),
#  ('short_model_ls', 0.0005433828297087266),
#  ('short_model_hummer', 0.0005345375202333475),
#  ('region_fresno / madera', 0.000529378811201721),
#  ('region_san antonio', 0.0005225765770478006),
#  ('region_tulsa', 0.0005223613775933158),
#  ('short_model_s5', 0.0005178118730165488),
#  ('state_md', 0.0005063822057668936),
#  ('region_redding', 0.0004811870584373868),
#  ('short_model_mkz', 0.00046819701582692425),
#  ('short_model_gla-class', 0.0004510634355021309),
#  ('region_boise', 0.0004510175039070913),
#  ('short_model_bus', 0.00044092564274776343),
#  ('short_model_428', 0.0004407194582059118),
#  ('short_model_c-hr', 0.00044031138463349875),
#  ('short_model_tribeca', 0.00043865358574557184),
#  ('region_texarkana', 0.00043720848558288745),
#  ('region_detroit metro', 0.0004360717237047),
#  ('short_model_sorento', 0.00043548869695952865),
#  ('short_model_sienna', 0.0004350064281921314),
#  ('region_missoula', 0.00043400010909203866),
#  ('region_lansing', 0.0004332381093783427),
#  ('short_model_frontier', 0.0004317396918571847),
#  ('region_saginaw-midland-baycity', 0.0004311386004188265),
#  ('short_model_m3', 0.00043025026034814676),
#  ('short_model_3-series', 0.00042995111675976964),
#  ('short_model_genesis', 0.00042938039489297594),
#  ('short_model_m35s', 0.00042938039489297594),
#  ('short_model_excursion', 0.0004291808001000374),
#  ('region_winston-salem', 0.0004282163772991725),
#  ('short_model_crosstrek', 0.0004277916874318718),
#  ('region_visalia-tulare', 0.00042668846803359435),
#  ('short_model_e-golf', 0.0004266125706426157),
#  ('short_model_qx80', 0.0004255465974692026),
#  ('short_model_camaro', 0.00042536105284419107),
#  ('region_springfield', 0.00042536105284419107),
#  ('short_model_gto', 0.00042502871219100857),
#  ('short_model_davidson', 0.0004250177572944282),
#  ('short_model_ssr', 0.0004247664479073091),
#  ('short_model_yaris', 0.0004234318701403483),
#  ('region_ft myers / SW florida', 0.00042333552402112315),
#  ('short_model_eurovan', 0.0004228573852200936),
#  ('short_model_i3', 0.000422429757750909),
#  ('region_akron / canton', 0.00042216284943934754),
#  ('region_southwest michigan', 0.00042216284943934754),
#  ('short_model_325is', 0.00042211523055373456),
#  ('region_scottsbluff / panhandle', 0.0004218668025603576),
#  ('region_lawrence', 0.00042185484269102594),
#  ('short_model_z3', 0.0004208598776818185),
#  ('region_olympic peninsula', 0.0004206469728900735),
#  ('region_la crosse', 0.00041968922594467367),
#  ('region_southern maryland', 0.0004190989217499754),
#  ('short_model_plymouth', 0.00041903387935338674),
#  ('state_mn', 0.00041903387935338674),
#  ('short_model_rogue', 0.0004187404148884592),
#  ('region_chicago', 0.00041861900707473756),
#  ('short_model_lx450', 0.0004178940782481989),
#  ('short_model_mkx', 0.0004163326449629915),
#  ('short_model_renegade', 0.000415099193889432),
#  ('short_model_GMC,', 0.00041378660242666197),
#  ('is_audi', 0.0004135369574176562),
#  ('state_in', 0.0004127966823251617),
#  ('region_SF bay area', 0.0004121821313351279),
#  ('short_model_s-class', 0.0004120843526674545),
#  ('short_model_sedona', 0.0004113381609921844),
#  ('short_model_cts', 0.0004107530426977434),
#  ('region_jacksonville', 0.00041070972769066834),
#  ('short_model_CLICK', 0.00041013606234455857),
#  ('region_roanoke', 0.00040981983319572917),
#  ('short_model_g37', 0.00040909862949664827),
#  ('short_model_town', 0.00040848164598529437),
#  ('region_tuscaloosa', 0.0004079578023241563),
#  ('region_corpus christi', 0.0004079007551784429),
#  ('region_zanesville / cambridge', 0.0004072130311945089),
#  ('short_model_F250', 0.0004066355378128459),
#  ('region_lexington', 0.00040649686055809506),
#  ('short_model_elcamino', 0.00040607030214830905),
#  ('region_st cloud', 0.0004058277243699714),
#  ('short_model_maxima', 0.00040570592130183215),
#  ('short_model_3', 0.0004051057646135151),
#  ('short_model_300', 0.0004051057646135151),
#  ('short_model_cayenne', 0.0004047702972470454),
#  ('region_savannah / hinesville', 0.00040378054553018153),
#  ('region_prescott', 0.00040262747052411524),
#  ('region_tri-cities', 0.0004025447511590624),
#  ('region_laredo', 0.0004015669096582712),
#  ('short_model_200', 0.00040105470696738006),
#  ('region_indianapolis', 0.00040105470696738006),
#  ('region_fort wayne', 0.00039996636312214924),
#  ('short_model_f350', 0.00039943201440884393),
#  ('region_eastern panhandle', 0.00039943201440884393),
#  ('short_model_w350', 0.00039864253873934),
#  ('short_model_g', 0.0003980408766412703),
#  ('short_model_sportage', 0.00039772383734722346),
#  ('region_atlanta', 0.0003972366326835235),
#  ('short_model_forte', 0.0003966867844162509),
#  ('region_chico', 0.00039610341428877025),
#  ('short_model_mdx', 0.00039577767134938704),
#  ('region_medford-ashland', 0.0003954736021085173),
#  ('region_fort collins / north CO', 0.00039488463455249694),
#  ('region_rochester', 0.00039288507404767374),
#  ('region_kennewick-pasco-richland', 0.00039235975397079753),
#  ('region_mankato', 0.0003919625860143964),
#  ('short_model_AM', 0.00039177103319498676),
#  ('state_al', 0.00039144038180035447),
#  ('region_lehigh valley', 0.0003899142984405083),
#  ('region_anchorage / mat-su', 0.00038968878409785816),
#  ('region_oklahoma city', 0.0003884263228532953),
#  ('short_model_nitro', 0.00038837313520556524),
#  ('region_santa fe / taos', 0.00038837313520556524),
#  ('region_las vegas', 0.00038832281150809783),
#  ('short_model_328xi', 0.00038825036829069165),
#  ('region_albuquerque', 0.0003859355811094836),
#  ('region_columbus', 0.0003859355811094836),
#  ('region_rockford', 0.00038440530521293445),
#  ('region_sarasota-bradenton', 0.0003834645882407407),
#  ('region_eugene', 0.00038195686377845715),
#  ('region_jackson', 0.00038195686377845715),
#  ('region_san diego', 0.0003811029669969593),
#  ('short_model_k900', 0.0003799465644954126),
#  ('region_new orleans', 0.00037924330448164934),
#  ('region_fredericksburg', 0.0003769503959348128),
#  ('short_model_xc90', 0.00037203590627771894),
#  ('short_model_isf', 0.00037181258970562386),
#  ('short_model_2500', 0.0003713469508957222),
#  ('region_amarillo', 0.0003713469508957222),
#  ('state_ks', 0.0003713469508957222),
#  ('short_model_verano', 0.00036973278454599767),
#  ('region_bakersfield', 0.0003686462457982985),
#  ('short_model_rav4', 0.0003663815720359498),
#  ('region_toledo', 0.0003656339208819421),
#  ('region_gainesville', 0.00036447265162324204),
#  ('short_model_xts', 0.00035952131882850783),
#  ('short_model_charger', 0.00035649307285989324),
#  ('short_model_cr-v', 0.00035649307285989324),
#  ('short_model_equinox', 0.00035649307285989324),
#  ('short_model_fiesta', 0.00035649307285989324),
#  ('short_model_isuzu', 0.00035649307285989324),
#  ('short_model_tl', 0.00035649307285989324),
#  ('state_wv', 0.00035649307285989324),
#  ('region_gold country', 0.00035586544421049187),
#  ('short_model_q7', 0.0003516105481351536),
#  ('short_model_suburban', 0.00034845912440301395),
#  ('short_model_ilx', 0.00033647702261846386),
#  ('region_inland empire', 0.00033476878517716595),
#  ('short_model_is250', 0.00033421225580615),
#  ('short_model_liberty', 0.00033421225580615),
#  ('short_model_s40', 0.00033421225580615),
#  ('region_fayetteville', 0.00033421225580615),
#  ('region_southeast alaska', 0.00033421225580615),
#  ('state_vt', 0.00033421225580615),
#  ('region_buffalo', 0.00032922037876132116),
#  ('region_susanville', 0.0003267980998158062),
#  ('short_model_cube', 0.0003218340241096259),
#  ('short_model_grand', 0.0003032666765648397),
#  ('short_model_avanger', 0.0002970775607165777),
#  ('short_model_glc', 0.0002970775607165777),
#  ('region_north jersey', 0.0002970775607165777),
#  ('region_north mississippi', 0.0002970775607165777),
#  ('region_ocala', 0.0002970775607165777),
#  ('region_rhode island', 0.0002970775607165777),
#  ('region_seattle-tacoma', 0.0002970775607165777),
#  ('state_ar', 0.0002970775607165777),
#  ('state_wa', 0.0002970775607165777),
#  ('short_model_willys', 0.00029442508249589403),
#  ('region_charlottesville', 0.00028965062169866333),
#  ('region_waco', 0.0002864676478338427),
#  ('short_model_encore', 0.00024113493199823586),
#  ('short_model_patriot', 0.0002228081705374333),
#  ('region_bellingham', 0.0002228081705374333),
#  ('state_or', 0.0002228081705374333),
#  ('short_model_leaf', 0.00022021572058102796),
#  ('region_twin falls', 0.0002187573686237406),
#  ('short_model_prius', 0.00021851192390342778),
#  ('region_pueblo', 0.0002157970735697971),
#  ('region_kalispell', 0.000211758526117288),
#  ('region_salem', 0.00021012508190315345),
#  ('region_phoenix', 0.0001461684806717187),
#  ('short_model_sequoia', 0.00014296857609485259),
#  ('region_sacramento', 0.0001421062533736054),
#  ('region_st louis, MO', 0.00010775149230908807),
#  ('region_central NJ', 8.599754833790957e-05),
#  ('short_model_-benz', 0.0),
#  ('short_model_1', 0.0),
#  ('short_model_124', 0.0),
#  ('short_model_128i', 0.0),
#  ('short_model_135i', 0.0),
#  ('short_model_163869', 0.0),
#  ('short_model_1928', 0.0),
#  ('short_model_1951', 0.0),
#  ('short_model_1954', 0.0),
#  ('short_model_1960s', 0.0),
#  ('short_model_1966', 0.0),
#  ('short_model_1968', 0.0),
#  ('short_model_1972', 0.0),
#  ('short_model_1977', 0.0),
#  ('short_model_1978', 0.0),
#  ('short_model_198.5', 0.0),
#  ('short_model_1988', 0.0),
#  ('short_model_1994', 0.0),
#  ('short_model_1999', 0.0),
#  ('short_model_2', 0.0),
#  ('short_model_2000', 0.0),
#  ('short_model_2002', 0.0),
#  ('short_model_2006', 0.0),
#  ('short_model_2007', 0.0),
#  ('short_model_2008', 0.0),
#  ('short_model_2009', 0.0),
#  ('short_model_2012', 0.0),
#  ('short_model_2015', 0.0),
#  ('short_model_2016', 0.0),
#  ('short_model_2017', 0.0),
#  ('short_model_2018', 0.0),
#  ('short_model_210', 0.0),
#  ('short_model_240', 0.0),
#  ('short_model_2500hd', 0.0),
#  ('short_model_280zx', 0.0),
#  ('short_model_3-window', 0.0),
#  ('short_model_3.2', 0.0),
#  ('short_model_300-series', 0.0),
#  ('short_model_300c', 0.0),
#  ('short_model_300s', 0.0),
#  ('short_model_300zx', 0.0),
#  ('short_model_3100', 0.0),
#  ('short_model_318i', 0.0),
#  ('short_model_320i', 0.0),
#  ('short_model_323i', 0.0),
#  ('short_model_325ci', 0.0),
#  ('short_model_325i', 0.0),
#  ('short_model_325xi', 0.0),
#  ('short_model_328', 0.0),
#  ('short_model_328ci', 0.0),
#  ('short_model_328d', 0.0),
#  ('short_model_328i', 0.0),
#  ('short_model_330i', 0.0),
#  ('short_model_335i', 0.0),
#  ('short_model_335xi', 0.0),
#  ('short_model_350', 0.0),
#  ('short_model_3500', 0.0),
#  ('short_model_3500hd', 0.0),
#  ('short_model_350z', 0.0),
#  ('short_model_370z', 0.0),
#  ('short_model_380sl', 0.0),
#  ('short_model_3i', 0.0),
#  ('short_model_4', 0.0),
#  ('short_model_4-runner', 0.0),
#  ('short_model_430i', 0.0),
#  ('short_model_435i', 0.0),
#  ('short_model_440xi', 0.0),
#  ('short_model_4500', 0.0),
#  ('short_model_4x4', 0.0),
#  ('short_model_5', 0.0),
#  ('short_model_5-series', 0.0),
#  ('short_model_50', 0.0),
#  ('short_model_500c', 0.0),
#  ('short_model_500l', 0.0),
#  ('short_model_500x', 0.0),
#  ('short_model_525i', 0.0),
#  ('short_model_528i', 0.0),
#  ('short_model_528xi', 0.0),
#  ('short_model_530', 0.0),
#  ('short_model_530i', 0.0),
#  ('short_model_535i', 0.0),
#  ('short_model_535xi', 0.0),
#  ('short_model_540i', 0.0),
#  ('short_model_545i', 0.0),
#  ('short_model_5500', 0.0),
#  ('short_model_5500hd', 0.0),
#  ('short_model_550i', 0.0),
#  ('short_model_5th', 0.0),
#  ('short_model_6', 0.0),
#  ('short_model_640', 0.0),
#  ('short_model_645ci', 0.0),
#  ('short_model_650i', 0.0),
#  ('short_model_650xi', 0.0),
#  ('short_model_7', 0.0),
#  ('short_model_750', 0.0),
#  ('short_model_750i', 0.0),
#  ('short_model_750xi', 0.0),
#  ('short_model_86', 0.0),
#  ('short_model_911', 0.0),
#  ('short_model_914', 0.0),
#  ('short_model_928', 0.0),
#  ('short_model_944', 0.0),
#  ('short_model_ACURA*', 0.0),
#  ('short_model_ALL', 0.0),
#  ('short_model_AMC', 0.0),
#  ('short_model_ASC', 0.0),
#  ('short_model_Acuarea', 0.0),
#  ('short_model_American', 0.0),
#  ('short_model_BUY', 0.0),
#  ('short_model_Bentley', 0.0),
#  ('short_model_Blue', 0.0),
#  ('short_model_Buicks', 0.0),
#  ('short_model_C', 0.0),
#  ('short_model_CHEVORLET', 0.0),
#  ('short_model_Champion', 0.0),
#  ('short_model_Chevey', 0.0),
#  ('short_model_Chevorlet', 0.0),
#  ('short_model_Comanche', 0.0),
#  ('short_model_Comet', 0.0),
#  ('short_model_D7FH173552', 0.0),
#  ('short_model_DODGE1500', 0.0),
#  ('short_model_Diahatsu', 0.0),
#  ('short_model_E46', 0.0),
#  ('short_model_EASY', 0.0),
#  ('short_model_Eagle', 0.0),
#  ('short_model_Emergency', 0.0),
#  ('short_model_F-250', 0.0),
#  ('short_model_FORD*', 0.0),
#  ('short_model_FORD/RANGER', 0.0),
#  ('short_model_FREIGHTLINER', 0.0),
#  ('short_model_FRRV', 0.0),
#  ('short_model_Flexible', 0.0),
#  ('short_model_FordE350', 0.0),
#  ('short_model_Freightliner', 0.0),
#  ('short_model_Frtlner', 0.0),
#  ('short_model_GCM', 0.0),
#  ('short_model_GEHL', 0.0),
#  ('short_model_GMX', 0.0),
#  ('short_model_GRAND', 0.0),
#  ('short_model_GULF', 0.0),
#  ('short_model_Genesis', 0.0),
#  ('short_model_Gx', 0.0),
#  ('short_model_HINO', 0.0),
#  ('short_model_HUMMER', 0.0),
#  ('short_model_Hino', 0.0),
#  ('short_model_Hobda', 0.0),
#  ('short_model_Hot', 0.0),
#  ('short_model_Hummer', 0.0),
#  ('short_model_IC', 0.0),
#  ('short_model_INTERNATIONAL', 0.0),
#  ('short_model_International', 0.0),
#  ('short_model_Isizu', 0.0),
#  ('short_model_Isuzu', 0.0),
#  ('short_model_JM1BK32F871604924', 0.0),
#  ('short_model_Janesville', 0.0),
#  ('short_model_Jauguar', 0.0),
#  ('short_model_Jayco', 0.0),
#  ('short_model_Kaiser', 0.0),
#  ('short_model_Lotus', 0.0),
#  ('short_model_MASERATI', 0.0),
#  ('short_model_MERCUTY', 0.0),
#  ('short_model_MERDECES', 0.0),
#  ('short_model_MGB', 0.0),
#  ('short_model_MITUSBISHI', 0.0),
#  ('short_model_MV-1', 0.0),
#  ('short_model_Maserati', 0.0),
#  ('short_model_Minin', 0.0),
#  ('short_model_Nascar', 0.0),
#  ('short_model_OLDSMOBILE', 0.0),
#  ('short_model_PLYMOUTH', 0.0),
#  ('short_model_PROGRAMS', 0.0),
#  ('short_model_Peterbilt', 0.0),
#  ('short_model_Pierce', 0.0),
#  ('short_model_Plymouth', 0.0),
#  ('short_model_QX', 0.0),
#  ('short_model_S60', 0.0),
#  ('short_model_SCION', 0.0),
#  ('short_model_SL', 0.0),
#  ('short_model_Saab', 0.0),
#  ('short_model_Sea', 0.0),
#  ('short_model_Sterling', 0.0),
#  ('short_model_Studebaker', 0.0),
#  ('short_model_Suzuki', 0.0),
#  ('short_model_THOMAS', 0.0),
#  ('short_model_Thomas', 0.0),
#  ('short_model_Town', 0.0),
#  ('short_model_Triumph', 0.0),
#  ('short_model_Voltswagon', 0.0),
#  ('short_model_Xx', 0.0),
#  ('short_model_a-class', 0.0),
#  ('short_model_a3', 0.0),
#  ('short_model_a3,', 0.0),
#  ('short_model_a5', 0.0),
#  ('short_model_a6', 0.0),
#  ('short_model_a7', 0.0),
#  ('short_model_a8', 0.0),
#  ('short_model_acadia', 0.0),
#  ('short_model_accent', 0.0),
#  ('short_model_accord', 0.0),
#  ('short_model_all', 0.0),
#  ('short_model_allante', 0.0),
#  ('short_model_allroad', 0.0),
#  ('short_model_am', 0.0),
#  ('short_model_amc', 0.0),
#  ('short_model_arcadia', 0.0),
#  ('short_model_armada', 0.0),
#  ('short_model_arteon', 0.0),
#  ('short_model_ascent', 0.0),
#  ('short_model_aspen', 0.0),
#  ('short_model_astra', 0.0),
#  ('short_model_astro', 0.0),
#  ('short_model_atlas', 0.0),
#  ('short_model_ats', 0.0),
#  ('short_model_aura', 0.0),
#  ('short_model_autobiography', 0.0),
#  ('short_model_avalon', 0.0),
#  ('short_model_avenger', 0.0),
#  ('short_model_aveo', 0.0),
#  ('short_model_aviator', 0.0),
#  ('short_model_azera', 0.0),
#  ('short_model_aztek', 0.0),
#  ('short_model_b-class', 0.0),
#  ('short_model_b-series', 0.0),
#  ('short_model_b2200', 0.0),
#  ('short_model_b2300', 0.0),
#  ('short_model_b2600i', 0.0),
#  ('short_model_baja', 0.0),
#  ('short_model_beetle', 0.0),
#  ('short_model_bel', 0.0),
#  ('short_model_belair', 0.0),
#  ('short_model_benz', 0.0),
#  ('short_model_blackwood', 0.0),
#  ('short_model_blazer', 0.0),
#  ('short_model_blue', 0.0),
#  ('short_model_bolt', 0.0),
#  ('short_model_bonanza', 0.0),
#  ('short_model_bonneville', 0.0),
#  ('short_model_boxster', 0.0),
#  ('short_model_bronco', 0.0),
#  ('short_model_brz', 0.0),
#  ('short_model_bug', 0.0),
#  ('short_model_c', 0.0),
#  ('short_model_c-10', 0.0),
#  ('short_model_c-7500', 0.0),
#  ('short_model_c-class', 0.0),
#  ('short_model_c-max', 0.0),
#  ('short_model_c/k', 0.0),
#  ('short_model_c10', 0.0),
#  ('short_model_c250', 0.0),
#  ('short_model_c280', 0.0),
#  ('short_model_c30', 0.0),
#  ('short_model_c300', 0.0),
#  ('short_model_c4500', 0.0),
#  ('short_model_c5500', 0.0),
#  ('short_model_c60', 0.0),
#  ('short_model_c6500', 0.0),
#  ('short_model_c70', 0.0),
#  ('short_model_c8500', 0.0),
#  ('short_model_cabellero', 0.0),
#  ('short_model_cabrio', 0.0),
#  ('short_model_caddilac', 0.0),
#  ('short_model_cadenza', 0.0),
#  ('short_model_caliber', 0.0),
#  ('short_model_camary', 0.0),
#  ('short_model_camero', 0.0),
#  ('short_model_canyon', 0.0),
#  ('short_model_capri', 0.0),
#  ('short_model_caprice', 0.0),
#  ('short_model_captiva', 0.0),
#  ('short_model_caravan', 0.0),
#  ('short_model_caravan/grand', 0.0),
#  ('short_model_cargo', 0.0),
#  ('short_model_cascada', 0.0),
#  ('short_model_cavalier', 0.0),
#  ('short_model_cayman', 0.0),
#  ('short_model_cc', 0.0),
#  ('short_model_cc300', 0.0),
#  ('short_model_cc4500', 0.0),
#  ('short_model_century', 0.0),
#  ('short_model_certified', 0.0),
#  ('short_model_cherokee', 0.0),
#  ('short_model_chevelle', 0.0),
#  ('short_model_chevorlet', 0.0),
#  ('short_model_chryler', 0.0),
#  ('short_model_chysler', 0.0),
#  ('short_model_city', 0.0),
#  ('short_model_cj-5', 0.0),
#  ('short_model_cj2a', 0.0),
#  ('short_model_cj5', 0.0),
#  ('short_model_cj7', 0.0),
#  ('short_model_cj8', 0.0),
#  ('short_model_cl-class', 0.0),
#  ('short_model_cla', 0.0),
#  ('short_model_cla-class', 0.0),
#  ('short_model_clarity', 0.0),
#  ('short_model_classic', 0.0),
#  ('short_model_classuc', 0.0),
#  ('short_model_clk', 0.0),
#  ('short_model_clk-class', 0.0),
#  ('short_model_clk350', 0.0),
#  ('short_model_cls-class', 0.0),
#  ('short_model_cls550', 0.0),
#  ('short_model_clubman', 0.0),
#  ('short_model_cmax', 0.0),
#  ('short_model_cobalt', 0.0),
#  ('short_model_colbalt', 0.0),
#  ('short_model_comet', 0.0),
#  ('short_model_commander', 0.0),
#  ('short_model_compass', 0.0),
#  ('short_model_concorde', 0.0),
#  ('short_model_conquest', 0.0),
#  ('short_model_continental', 0.0),
#  ('short_model_convertible', 0.0),
#  ('short_model_corsair', 0.0),
#  ('short_model_cougar', 0.0),
#  ('short_model_country', 0.0),
#  ('short_model_countryman', 0.0),
#  ('short_model_coupe', 0.0),
#  ('short_model_crew', 0.0),
#  ('short_model_crossfire', 0.0),
#  ('short_model_crosstour', 0.0),
#  ('short_model_crown', 0.0),
#  ('short_model_crv', 0.0),
#  ('short_model_crz', 0.0),
#  ('short_model_ct', 0.0),
#  ('short_model_ct4', 0.0),
#  ('short_model_ct5', 0.0),
#  ('short_model_ct6', 0.0),
#  ('short_model_cts-v', 0.0),
#  ('short_model_cts4', 0.0),
#  ('short_model_cvr', 0.0),
#  ('short_model_cx-3', 0.0),
#  ('short_model_cx-5', 0.0),
#  ('short_model_cx-7', 0.0),
#  ('short_model_cx-9', 0.0),
#  ('short_model_cx7', 0.0),
#  ('short_model_cx9', 0.0),
#  ('short_model_d50', 0.0),
#  ('short_model_dakota', 0.0),
#  ('short_model_dealer*', 0.0),
#  ('short_model_defender', 0.0),
#  ('short_model_deisel', 0.0),
#  ('short_model_deluxe', 0.0),
#  ('short_model_denali', 0.0),
#  ('short_model_deville', 0.0),
#  ('short_model_diesel', 0.0),
#  ('short_model_discovery', 0.0),
#  ('short_model_dts', 0.0),
#  ('short_model_dump', 0.0),
#  ('short_model_duramax', 0.0),
#  ('short_model_durango', 0.0),
#  ('short_model_durangon', 0.0),
#  ('short_model_e', 0.0),
#  ('short_model_e-150', 0.0),
#  ('short_model_e-250', 0.0),
#  ('short_model_e-450', 0.0),
#  ('short_model_e-class', 0.0),
#  ('short_model_e-pace', 0.0),
#  ('short_model_e-series', 0.0),
#  ('short_model_e150', 0.0),
#  ('short_model_e250', 0.0),
#  ('short_model_e320', 0.0),
#  ('short_model_e350', 0.0),
#  ('short_model_e450', 0.0),
#  ('short_model_e46', 0.0),
#  ('short_model_e500', 0.0),
#  ('short_model_echo', 0.0),
#  ('short_model_eclipse', 0.0),
#  ('short_model_econoline', 0.0),
#  ('short_model_ecosport', 0.0),
#  ('short_model_el', 0.0),
#  ('short_model_eldorado', 0.0),
#  ('short_model_element', 0.0),
#  ('short_model_enclave', 0.0),
#  ('short_model_endeavor', 0.0),
#  ('short_model_envision', 0.0),
#  ('short_model_envoy', 0.0),
#  ('short_model_eos', 0.0),
#  ('short_model_eqinox', 0.0),
#  ('short_model_es', 0.0),
#  ('short_model_es300', 0.0),
#  ('short_model_es330', 0.0),
#  ('short_model_es350', 0.0),
#  ('short_model_escape-se,', 0.0),
#  ('short_model_escort', 0.0),
#  ('short_model_evoque', 0.0),
#  ('short_model_expedition', 0.0),
#  ('short_model_f', 0.0),
#  ('short_model_f-100', 0.0),
#  ('short_model_f-350sd', 0.0),
#  ('short_model_f-450', 0.0),
#  ('short_model_f-450sd', 0.0),
#  ('short_model_f-550', 0.0),
#  ('short_model_f-650', 0.0),
#  ('short_model_f-750', 0.0),
#  ('short_model_f-pace', 0.0),
#  ('short_model_f-type', 0.0),
#  ('short_model_f1', 0.0),
#  ('short_model_f100', 0.0),
#  ('short_model_f450', 0.0),
#  ('short_model_f450sd', 0.0),
#  ('short_model_f50', 0.0),
#  ('short_model_f550', 0.0),
#  ('short_model_f600', 0.0),
#  ('short_model_f700', 0.0),
#  ('short_model_f750', 0.0),
#  ('short_model_falcon', 0.0),
#  ('short_model_fe', 0.0),
#  ('short_model_fiero', 0.0),
#  ('short_model_firebird', 0.0),
#  ('short_model_five', 0.0),
#  ('short_model_fj40', 0.0),
#  ('short_model_fleetmaster', 0.0),
#  ('short_model_fleetwood', 0.0),
#  ('short_model_flex', 0.0),
#  ('short_model_fords', 0.0),
#  ('short_model_forester', 0.0),
#  ('short_model_forte5', 0.0),
#  ('short_model_foxbody', 0.0),
#  ('short_model_freestar', 0.0),
#  ('short_model_freestyle', 0.0),
#  ('short_model_freightliner', 0.0),
#  ('short_model_fuso', 0.0),
#  ('short_model_fx35', 0.0),
#  ('short_model_fx45', 0.0),
#  ('short_model_g-class', 0.0),
#  ('short_model_g.', 0.0),
#  ('short_model_g20', 0.0),
#  ('short_model_g30', 0.0),
#  ('short_model_g35', 0.0),
#  ('short_model_g35x', 0.0),
#  ('short_model_g37s', 0.0),
#  ('short_model_g37x', 0.0),
#  ('short_model_g4500', 0.0),
#  ('short_model_g5', 0.0),
#  ('short_model_g6', 0.0),
#  ('short_model_g8', 0.0),
#  ('short_model_galant', 0.0),
#  ('short_model_ghia', 0.0),
#  ('short_model_gl', 0.0),
#  ('short_model_gl-class', 0.0),
#  ('short_model_gl450', 0.0),
#  ('short_model_gla', 0.0),
#  ('short_model_gladiator', 0.0),
#  ('short_model_glc-class', 0.0),
#  ('short_model_gle', 0.0),
#  ('short_model_gle-class', 0.0),
#  ('short_model_glk', 0.0),
#  ('short_model_glk-class', 0.0),
#  ('short_model_glk350', 0.0),
#  ('short_model_gls', 0.0),
#  ('short_model_gmc/chev', 0.0),
#  ('short_model_gmce', 0.0),
#  ('short_model_gmt-400', 0.0),
#  ('short_model_gr', 0.0),
#  ('short_model_grandville', 0.0),
#  ('short_model_grumman', 0.0),
#  ('short_model_gs', 0.0),
#  ('short_model_gs350', 0.0),
#  ('short_model_gs430', 0.0),
#  ('short_model_gt', 0.0),
#  ('short_model_gt-r', 0.0),
#  ('short_model_gti', 0.0),
#  ('short_model_gx460', 0.0),
#  ('short_model_gx470', 0.0),
#  ('short_model_hardbody', 0.0),
#  ('short_model_hardtop', 0.0),
#  ('short_model_hearse', 0.0),
#  ('short_model_hhr', 0.0),
#  ('short_model_hiace', 0.0),
#  ('short_model_high', 0.0),
#  ('short_model_hr-v', 0.0),
#  ('short_model_hse', 0.0),
#  ('short_model_hyndai', 0.0),
#  ('short_model_i-miev', 0.0),
#  ('short_model_i30', 0.0),
#  ('short_model_i35', 0.0),
#  ('short_model_insight', 0.0),
#  ('short_model_international', 0.0),
#  ('short_model_ion', 0.0),
#  ('short_model_ioniq', 0.0),
#  ('short_model_is', 0.0),
#  ('short_model_is300', 0.0),
#  ('short_model_jeepster', 0.0),
#  ('short_model_jimmy', 0.0),
#  ('short_model_jouney', 0.0),
#  ('short_model_journey', 0.0),
#  ('short_model_juke', 0.0),
#  ('short_model_jx35', 0.0),
#  ('short_model_k10', 0.0),
#  ('short_model_k20', 0.0),
#  ('short_model_k30', 0.0),
#  ('short_model_k5', 0.0),
#  ('short_model_kicks', 0.0),
#  ('short_model_kodiak', 0.0),
#  ('short_model_l', 0.0),
#  ('short_model_l300', 0.0),
#  ('short_model_lacrosse', 0.0),
#  ('short_model_lancer', 0.0),
#  ('short_model_landcruiser', 0.0),
#  ('short_model_legacy', 0.0),
#  ('short_model_legend', 0.0),
#  ('short_model_lemans', 0.0),
#  ('short_model_lesabre', 0.0),
#  ('short_model_lifted', 0.0),
#  ('short_model_lightning', 0.0),
#  ('short_model_limousine', 0.0),
#  ('short_model_long', 0.0),
#  ('short_model_lr2', 0.0),
#  ('short_model_lr3', 0.0),
#  ('short_model_lr4', 0.0),
#  ('short_model_ltd', 0.0),
#  ('short_model_lucerne', 0.0),
#  ('short_model_lx', 0.0),
#  ('short_model_m', 0.0),
#  ('short_model_m-class', 0.0),
#  ('short_model_m35', 0.0),
#  ('short_model_m5', 0.0),
#  ('short_model_macan', 0.0),
#  ('short_model_magnum', 0.0),
#  ('short_model_mallinia', 0.0),
#  ('short_model_marineer,premier', 0.0),
#  ('short_model_mariner', 0.0),
#  ('short_model_mark', 0.0),
#  ('short_model_maserati', 0.0),
#  ('short_model_matrix', 0.0),
#  ('short_model_maximum', 0.0),
#  ('short_model_mazda2', 0.0),
#  ('short_model_mazda5', 0.0),
#  ('short_model_mazda6', 0.0),
#  ('short_model_mazda6i', 0.0),
#  ('short_model_md-x', 0.0),
#  ('short_model_mercades', 0.0),
#  ('short_model_mercedes-amg', 0.0),
#  ('short_model_metris', 0.0),
#  ('short_model_mg', 0.0),
#  ('short_model_miata', 0.0),
#  ('short_model_milan', 0.0),
#  ('short_model_mkc', 0.0),
#  ('short_model_mks', 0.0),
#  ('short_model_mkt', 0.0),
#  ('short_model_ml', 0.0),
#  ('short_model_ml350', 0.0),
#  ('short_model_ml500', 0.0),
#  ('short_model_model', 0.0),
#  ('short_model_monte', 0.0),
#  ('short_model_montero', 0.0),
#  ('short_model_mountaineer', 0.0),
#  ('short_model_mpv', 0.0),
#  ('short_model_mr2', 0.0),
#  ('short_model_murano', 0.0),
#  ('short_model_mx-5', 0.0),
#  ('short_model_nautilus', 0.0),
#  ('short_model_navigator', 0.0),
#  ('short_model_neon', 0.0),
#  ('short_model_new', 0.0),
#  ('short_model_newport', 0.0),
#  ('short_model_niro', 0.0),
#  ('short_model_nova', 0.0),
#  ('short_model_nv', 0.0),
#  ('short_model_nv1500', 0.0),
#  ('short_model_nv200', 0.0),
#  ('short_model_nv2500', 0.0),
#  ('short_model_nv2500hd', 0.0),
#  ('short_model_nx', 0.0),
#  ('short_model_nx300', 0.0),
#  ('short_model_oddyssey', 0.0),
#  ('short_model_oldsmobile', 0.0),
#  ('short_model_optima', 0.0),
#  ('short_model_optimia', 0.0),
#  ('short_model_outback', 0.0),
#  ('short_model_outlook', 0.0),
#  ('short_model_paceman', 0.0),
#  ('short_model_pacifica', 0.0),
#  ('short_model_panamera', 0.0),
#  ('short_model_panel', 0.0),
#  ('short_model_park', 0.0),
#  ('short_model_passat', 0.0),
#  ('short_model_passport', 0.0),
#  ('short_model_pathfinder', 0.0),
#  ('short_model_phaeton', 0.0),
#  ('short_model_pick', 0.0),
#  ('short_model_pickup', 0.0),
#  ('short_model_pontaic', 0.0),
#  ('short_model_prelude', 0.0),
#  ('short_model_prizm', 0.0),
#  ('short_model_protege', 0.0),
#  ('short_model_pt', 0.0),
#  ('short_model_putback', 0.0),
#  ('short_model_q3', 0.0),
#  ('short_model_q5', 0.0),
#  ('short_model_q50', 0.0),
#  ('short_model_q60', 0.0),
#  ('short_model_q70', 0.0),
#  ('short_model_quattro', 0.0),
#  ('short_model_quest', 0.0),
#  ('short_model_qx56', 0.0),
#  ('short_model_qx60', 0.0),
#  ('short_model_qx70', 0.0),
#  ('short_model_r-class', 0.0),
#  ('short_model_r32', 0.0),
#  ('short_model_rabbit', 0.0),
#  ('short_model_rainier', 0.0),
#  ('short_model_ram1500', 0.0),
#  ('short_model_ram2500', 0.0),
#  ('short_model_ramcharger', 0.0),
#  ('short_model_range', 0.0),
#  ('short_model_ranger', 0.0),
#  ('short_model_rat', 0.0),
#  ('short_model_rav', 0.0),
#  ('short_model_rc', 0.0),
#  ('short_model_rdx', 0.0),
#  ('short_model_reatta', 0.0),
#  ('short_model_rebel', 0.0),
#  ('short_model_rendezvous', 0.0),
#  ('short_model_replica', 0.0),
#  ('short_model_ridgeline', 0.0),
#  ('short_model_rio', 0.0),
#  ('short_model_rivera', 0.0),
#  ('short_model_riviera', 0.0),
#  ('short_model_rl', 0.0),
#  ('short_model_rlx', 0.0),
#  ('short_model_roadmaster', 0.0),
#  ('short_model_roadster', 0.0),
#  ('short_model_romeo', 0.0),
#  ('short_model_rondo', 0.0),
#  ('short_model_rouge', 0.0),
#  ('short_model_routan', 0.0),
#  ('short_model_rs', 0.0),
#  ...]

# %%
zero_weight = [t[0] for t in f_imp_list if t[1] == 0]
x_train = x_train.drop(zero_weight, axis = 1)
x_test = x_test.drop(zero_weight, axis = 1)
x_test.columns
# Out:
# Index(['id', 'is_audi', 'is_ford', 'is_chevrolet', 'is_toyota', 'x0_diesel',
#        'x0_electric', 'x0_gas', 'x0_hybrid', 'x0_other',
#        ...
#        'lat_std', 'long_std', 'year_std', 'desc_len_std', 'model_in_desc_std',
#        'model_len_std', 'model_word_count_std', 'month_std', 'dayofweek_std',
#        'diff_years_std'],
#       dtype='object', length=371)

# %%
clf.fit(x_train, y_train)
predicted_train = clf.predict(x_train)
predicted_test = clf.predict(x_test)
print(accuracy_score(y_train, predicted_train))
print(accuracy_score(y_test, predicted_test))
# Out:
# 1.0
# 0.6732501732501732

# %% [markdown]
# 1. *Подготовка модели случайного леса*
#
# Обучите простую модель классификации с помощью RandomForestClassifier. Для этого сделайте следующие шаги:
# 1. На новых урезанных семплах тренировочной и тестовой выборок обучите модель случайного леса с зафиксированным random_state=50.
#
# 2. Сделайте предикт и посчитайте точность модели и матрицу ошибок. Сравните с предыдущей моделью дерева решений. Есть ли случаи, когда модель из пункта 1 отрабатывает лучше, чем модель случайного леса?

# %%
from sklearn.ensemble import RandomForestClassifier
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 50)
rf_clf = RandomForestClassifier()
rf_clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predicted_train_rf = rf_clf.predict(x_train)
predicted_test_rf = rf_clf.predict(x_test)
print(accuracy_score(y_train, predicted_train_rf))
print(accuracy_score(y_test, predicted_test_rf))
# Out:
# 1.0
# 0.761954261954262

# %%
confusion_matrix(y_test, predicted_test)
# Out:
# array([[297, 326, 323],
#        [334, 338, 303],
#        [343, 301, 321]], dtype=int64)

# %% [markdown]
# 2. *Тюнинг модели случайного леса*
#
# Увеличьте точность модели на тестовом датасете RandomForestClassifier c помощью тюнинга параметров.
#
# Параметры, которые можно настраивать для увеличения точности:
#
# ```
#     `bootstrap'
#     'max_depth'
#     'max_features'
#     'min_samples_leaf'
#     'min_samples_split'
#     'random_state'
#     'n_estimators'
#
# ```
#
#
#
# С описанием каждого из параметров можно ознакомиться в документации:
#
#
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
#
# Задание засчитывается, если значение метрики строго выше 0,76 на тестовом датасете.

# %%
from sklearn.model_selection import RandomizedSearchCV
param_grid = {
    'bootstrap':[True, False],
    'max_depth' : list(range(1,100,5)),
    'max_features': ['sqrt', 'log2'],
    'min_samples_leaf': list(range(1,10)),
    'min_samples_split':list(range(2,10)),
    'random_state': list(range(1,100)),
    'n_estimators':list(range(50, 501, 100))
}
randomized_search_rf = RandomizedSearchCV(
   estimator=rf_clf,
   param_distributions=param_grid,
   n_iter=20,
   scoring='accuracy',
   verbose=1,
   n_jobs=-1
)
randomized_search_rf.fit(x_train, y_train)
best_params = randomized_search_rf.best_params_
print(best_params)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# {'random_state': 50, 'n_estimators': 450, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 81, 'bootstrap': False}

# %%
rf_clf_tuned = RandomForestClassifier(
    random_state= best_params['random_state'], 
    n_estimators= best_params['n_estimators'],
    min_samples_split= best_params['min_samples_split'],
    min_samples_leaf= best_params['min_samples_leaf'],
    max_features= best_params['max_features'], 
    max_depth= best_params['max_depth'], 
    bootstrap= best_params['bootstrap']
)
rf_clf_tuned.fit(x_train, y_train)
predicted_tuned_test = rf_clf_tuned.predict(x_test)
print(accuracy_score(y_test, predicted_tuned_test))
#Fitting 5 folds for each of 20 candidates, totalling 100 fits
#{'random_state': 50, 'n_estimators': 450, 'min_samples_split': 3, 
 #'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 81, 'bootstrap': False}
# Out:
# 0.7668052668052668

# %% [markdown]
# 3. *Анализ влияния фичей на модель*
#
# Во всех задачах до вы работали над подготовленным датасетом, где фичи были заранее извлечены из текстовых переменных, отскейлены и пропущены через One Hot Encoder. Сравним, какой была бы предсказательная способность модели, если бы мы использовали только сырые данные из исходного датасета. Для этого проделайте следующие шаги:
#
# 1. Загрузите датасет `vehicles_dataset_old.csv`.
# 2. Удалите из него переменную `price` и все строковые колонки. Дерево решений и случайный лес не умеют самостоятельно работать со строковыми значениями.
# 3. Сформируйте x_train и x_test так же, как они были сформированы в предыдущих заданиях.
# 4. Обучите свою лучшую модель случайного леса на новых данных и замерьте качество. Убедитесь, что оно ухудшилось.
# 5. Найдите три фичи, которые лучшим образом повлияли на предсказательную способность модели.

# %%
df_old = pd.read_csv('vehicles_dataset_old.csv')
df_old.head()
# Out:
#            id                                                url  \
# 0  7308295377  https://chattanooga.craigslist.org/ctd/d/chatt...
# 1  7316380095  https://newjersey.craigslist.org/ctd/d/carlsta...
# 2  7313733749  https://reno.craigslist.org/ctd/d/atlanta-2017...
# 3  7308210929  https://fayetteville.craigslist.org/ctd/d/rale...
# 4  7303797340  https://knoxville.craigslist.org/ctd/d/knoxvil...
#
#          region                           region_url  price  year  \
# 0   chattanooga   https://chattanooga.craigslist.org  54990  2020
# 1  north jersey     https://newjersey.craigslist.org  16942  2016
# 2  reno / tahoe          https://reno.craigslist.org  35590  2017
# 3  fayetteville  https://fayetteville.craigslist.org  14500  2013
# 4     knoxville     https://knoxville.craigslist.org  14590  2012
#
#   manufacturer                   model    fuel  odometer title_status  \
# 0          ram  2500 crew cab big horn  diesel     27442        clean
# 1         ford    explorer 4wd 4dr xlt   other     60023        clean
# 2   volkswagen        golf r hatchback     gas     14048        clean
# 3       toyota                    rav4     gas    117291        clean
# 4          bmw  1 series 128i coupe 2d   other     80465        clean
#
#   transmission                                          image_url  \
# 0        other  https://images.craigslist.org/00N0N_1xMPvfxRAI...
# 1    automatic  https://images.craigslist.org/00x0x_26jl9F0cnL...
# 2        other  https://images.craigslist.org/00y0y_eeZjWeiSfb...
# 3    automatic  https://images.craigslist.org/00606_iGe5iXidib...
# 4        other  https://images.craigslist.org/00F0F_5UAXmOzC18...
#
#                                          description state        lat  \
# 0  Carvana is the safer way to buy a car During t...    tn  35.060000
# 1  ***Call Us for more information at: 201-635-14...    nj  40.821805
# 2  Carvana is the safer way to buy a car During t...    ca  33.779214
# 3  2013 Toyota RAV4 XLE 4dr SUV     Offered by: R...    nc  35.715954
# 4  Carvana is the safer way to buy a car During t...    tn  35.970000
#
#         long              posting_date price_category  \
# 0 -85.250000  2021-04-17T12:30:50-0400           high
# 1 -74.061962  2021-05-03T15:40:21-0400         medium
# 2 -84.411811  2021-04-28T03:52:20-0700           high
# 3 -78.655304  2021-04-17T10:08:57-0400         medium
# 4 -83.940000  2021-04-08T15:10:56-0400         medium
#
#                         date
# 0  2021-04-17 16:30:50+00:00
# 1  2021-05-03 19:40:21+00:00
# 2  2021-04-28 10:52:20+00:00
# 3  2021-04-17 14:08:57+00:00
# 4  2021-04-08 19:10:56+00:00

# %%
df_old_prepared = df_old.copy()
df_old_prepared = df_old_prepared.drop(['price'], axis=1)
df_old_prepared = df_old_prepared.select_dtypes(exclude=['object'])
df_old_prepared

x = df_old_prepared
y = df_prepared['price_category']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

#rf_clf = RandomForestClassifier()
rf_clf_tuned.fit(x_train, y_train)

predicted_train_rf_tuned = rf_clf_tuned.predict(x_train)
predicted_test_rf_tuned = rf_clf_tuned.predict(x_test)

print(accuracy_score(y_train, predicted_train_rf_tuned))
print(accuracy_score(y_test, predicted_test_rf_tuned))
# Out:
# 1.0
# 0.6334026334026334

# %%
print(rf_clf_tuned.feature_importances_)
f_imp_list = list(zip(x_train.columns, clf.feature_importances_))
f_imp_list.sort(key=lambda x: x[1], reverse=True)
f_imp_list[:3]
# Out:
# [0.1655996  0.2369763  0.27035417 0.1628535  0.16421643]
# [('id', 0.03432948387647825),
#  ('lat', 0.0043214465190723654),
#  ('odometer', 0.004026577383414722)]
